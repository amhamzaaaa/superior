# %% [markdown]
# # data exploration

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\123\Desktop\university\sem 3\AI lab\ML\data.csv")
df
# Out:
#                 date         price  bedrooms  bathrooms  sqft_living  \
# 0      5/2/2014 0:00  3.130000e+05       3.0       1.50       1340.0
# 1      5/2/2014 0:00  2.384000e+06       5.0       2.50       3650.0
# 2      5/2/2014 0:00  3.420000e+05       3.0       2.00       1930.0
# 3      5/2/2014 0:00  4.200000e+05       3.0       2.25       2000.0
# 4      5/2/2014 0:00  5.500000e+05       4.0       2.50       1940.0
# ...              ...           ...       ...        ...          ...
# 4595   7/9/2014 0:00  3.081667e+05       3.0       1.75       1510.0
# 4596   7/9/2014 0:00  5.343333e+05       3.0        NaN       1460.0
# 4597   7/9/2014 0:00  4.169042e+05       3.0        NaN       3010.0
# 4598  7/10/2014 0:00  2.034000e+05       4.0       2.00       2090.0
# 4599  7/10/2014 0:00  2.206000e+05       3.0       2.50       1490.0
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 0       7912.0     1.5         0.0   0.0          3      1340.0
# ...

# %%
df.head()
# Out:
#             date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  5/2/2014 0:00   313000.0       3.0       1.50       1340.0    7912.0
# 1  5/2/2014 0:00  2384000.0       5.0       2.50       3650.0    9050.0
# 2  5/2/2014 0:00   342000.0       3.0       2.00       1930.0   11947.0
# 3  5/2/2014 0:00   420000.0       3.0       2.25       2000.0    8030.0
# 4  5/2/2014 0:00   550000.0       4.0       2.50       1940.0   10500.0
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5         0.0   0.0          3      1340.0            0.0    1955.0
# 1     2.0         0.0   4.0          5      3370.0          280.0    1921.0
# 2     1.0         0.0   0.0          4      1930.0            0.0    1966.0
# 3     1.0         0.0   0.0          4      1000.0         1000.0    1963.0
# 4     1.0         0.0   0.0          4      1140.0          800.0    1976.0
#
#    yr_renovated                    street       city  statezip country
# ...

# %%
df.count()
# Out:
# date             4600
# price            4597
# bedrooms         4595
# bathrooms        4598
# sqft_living      4598
# sqft_lot         4598
# floors           4598
# waterfront       4595
# view             4598
# condition        4600
# sqft_above       4597
# sqft_basement    4597
# yr_built         4594
# yr_renovated     4600
# street           4597
# city             4596
# statezip         4597
# country          4594
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4569 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4569 non-null   object
#  1   price          4569 non-null   float64
#  2   bedrooms       4569 non-null   float64
#  3   bathrooms      4569 non-null   float64
#  4   sqft_living    4569 non-null   float64
#  5   sqft_lot       4569 non-null   float64
#  6   floors         4569 non-null   float64
#  7   waterfront     4569 non-null   float64
#  8   view           4569 non-null   float64
#  9   condition      4569 non-null   int64
#  10  sqft_above     4569 non-null   float64
#  11  sqft_basement  4569 non-null   float64
#  12  yr_built       4569 non-null   float64
#  13  yr_renovated   4569 non-null   int64
#  14  street         4569 non-null   object
#  15  city           4569 non-null   object
#  16  statezip       4569 non-null   object
# ...

# %%
df.dropna(axis = 0, inplace = True)

# %%
df.plot(kind = 'box', figsize= (20,8))
# Out:
# <Axes: >

# %%
df.plot(x= 'price', y= 'sqft_living', kind= 'scatter', figsize = (20,8))
# Out:
# <Axes: xlabel='price', ylabel='sqft_living'>
